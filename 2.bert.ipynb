# %% [markdown]
# # 用 Bert 生成词向量
#
# 用 Bert 生成中英文句子向量

# %%
# !pip install --upgrade ipywidgets

# %%
from transformers import BertModel, BertTokenizer
import torch

# %%
EN_BERT_PATH = './data/bert-base-uncased'
CN_BERT_PATH = './data/bert-base-chinese'

# %% [markdown]
# ## 1. 英文句子向量
#
# 下载 [bert-base-uncased](https://huggingface.co/google-bert/bert-base-uncased) 的模型文件：
#
# ```bash
# conda install pytorch -y
# pip install -U huggingface_hub
# export HF_ENDPOINT=https://hf-mirror.com
# huggingface-cli download --resume-download bert-base-uncased --local-dir ./data/bert-base-uncased
# ```

# %%
# 加载模型
tokenizer = BertTokenizer.from_pretrained(EN_BERT_PATH)
model = BertModel.from_pretrained(EN_BERT_PATH)
# Out:
# Some weights of the model checkpoint at ./data/bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
en_text = "china"
en_encoded_input = tokenizer(en_text, return_tensors='pt')
en_encoded_input
# Out:
# {'input_ids': tensor([[ 101, 2859,  102]]), 'token_type_ids': tensor([[0, 0, 0]]), 'attention_mask': tensor([[1, 1, 1]])}

# %%
with torch.no_grad():
    outputs = model(**en_encoded_input)
    embeddings = outputs.last_hidden_state.mean(dim=1)

embeddings.shape
# Out:
# torch.Size([1, 768])

# %%
embeddings
# Out:
# tensor([[-7.2748e-02, -6.0616e-02, -3.6487e-01, -3.6696e-02, -2.1376e-01,
#          -1.2931e-01,  9.5531e-02,  1.6451e-01,  6.3211e-02, -1.1386e-01,
#           1.5692e-02, -2.0598e-01, -5.4117e-02,  1.3845e-01, -5.3391e-01,
#          -1.0799e-01, -2.5073e-01,  1.4953e-01,  1.6047e-02,  1.5631e-01,
#           2.2903e-01, -1.0620e-01,  2.0776e-01,  1.2699e-01, -5.3219e-02,
#           2.6649e-01, -1.5513e-01, -1.9328e-02, -2.1553e-01, -1.6270e-01,
#          -2.0865e-01, -1.7892e-01,  2.3612e-01,  3.7936e-01,  2.1672e-01,
#          -6.1220e-02,  8.7686e-02,  1.0306e-01, -3.0434e-01, -1.2954e-01,
#          -3.2665e-01, -1.4788e-01,  2.1459e-02,  9.8637e-02,  5.6040e-01,
#          -2.7032e-01, -7.5218e-02,  2.6385e-01, -1.7370e-01,  5.4277e-02,
#          -3.2903e-01,  1.4791e-01,  1.3729e-01,  2.1489e-01,  5.0297e-02,
#           4.6308e-01,  5.4485e-02, -3.3327e-01,  9.9945e-02, -9.7959e-02,
#           2.2447e-01,  2.0381e-02, -2.6579e-01, -2.1536e-01,  2.8245e-01,
#           6.0419e-02,  2.7709e-01,  1.5189e-01, -3.5358e-01, -2.2715e-02,
#          -2.4426e-01, -3.4591e-01,  5.7894e-02,  8.2279e-02,  2.1067e-03,
#          -9.6755e-02, -3.3833e-01,  2.9080e-01,  2.5596e-01, -1.5422e-01,
#           1.9753e-01,  1.5960e-01,  1.8002e-01,  3.4851e-01,  3.2354e-02,
#          -2.6944e-02, -1.2456e-01,  1.1924e-01, -1.4092e-01,  3.5572e-01,
#          -1.9776e-02,  9.9166e-02,  4.0151e-02, -4.9286e-02, -1.0378e-01,
#           1.4025e-01, -3.0114e-01,  2.7763e-01, -7.2223e-03, -2.0929e-01,
#           2.1162e-02, -2.8937e-02,  1.3951e-01,  3.7018e-01,  1.4900e-01,
#          -1.0852e-01,  1.3237e-02,  2.5527e-02, -1.6917e-01, -6.2645e-01,
#           2.7607e-01,  2.5991e-02,  2.2188e-01,  2.4187e-02, -6.1280e-02,
#           3.0030e-01, -2.1454e-02, -3.9371e-01,  2.2416e-01, -9.8789e-02,
#          -3.0765e-01, -1.9959e-01, -2.8078e-01,  6.2101e-01,  3.8995e-02,
#           1.9822e-02, -4.3850e-02, -3.7797e-01, -2.4700e-01, -1.2535e-01,
#          -6.3789e-02,  4.1589e-01,  8.3426e-02,  3.2364e-01, -9.5709e-02,
#           1.1500e-01, -3.9186e-02,  2.1384e-01, -3.1987e-01, -1.1087e-01,
#           3.4677e-02,  5.9724e-01, -6.2549e-01, -4.9197e-01,  3.1174e-02,
#           2.0607e-01,  4.1443e-01, -1.5177e-01,  3.8870e-01, -1.5637e-01,
#           2.5638e-01,  1.9692e-01, -1.4879e-01,  9.8086e-02, -2.8420e-01,
#          -3.3608e-01,  1.4445e-01, -7.9876e-02,  2.4275e-01,  5.8627e-01,
#           2.1636e-01, -1.0196e-01, -8.1308e-02,  7.8604e-02, -5.4888e-01,
#           1.7429e-01, -1.0358e-01,  4.8821e-01,  1.6253e-01, -1.1969e-01,
#          -6.2882e-01, -1.1407e-01,  6.5193e-01,  1.8048e-01,  1.0661e-01,
#           1.4190e-01, -2.9292e-01,  2.7000e-01,  1.0004e-01, -1.2475e-01,
#          -2.8572e+00,  4.2014e-01, -2.1505e-01,  1.9593e-01,  4.1069e-01,
#          -2.8830e-01,  1.3353e-02, -3.3910e-01,  5.2974e-04, -8.2525e-02,
#          -1.1824e-01, -5.9523e-02, -2.9381e-01,  3.5469e-01,  5.2342e-02,
#          -2.1092e-01, -1.5233e-01, -3.2750e-01,  2.9157e-01,  1.0159e-01,
#           1.4721e-01, -1.0621e-01, -4.3229e-02,  6.0728e-01,  9.4432e-02,
#           6.5652e-01,  1.2311e-01, -2.8157e-01,  3.4755e-01,  3.3344e-02,
#          -6.8431e-01,  3.1565e-01, -4.5267e-02, -1.9335e-01,  2.7582e-01,
#          -3.7196e-01,  1.0136e-01, -1.3602e-01, -6.5564e-01,  9.1423e-02,
#          -3.7308e-02, -1.0596e-01, -1.6688e-01,  1.3002e-01, -6.1333e-02,
#          -1.8863e-01,  1.6628e-01,  5.3899e-01,  9.8677e-02,  4.7980e-02,
#          -2.7823e-03, -1.4156e-01,  3.0423e-01,  1.3689e-02, -5.9447e-01,
#           2.5881e-01,  6.9294e-02, -1.8633e-01, -5.0406e-02, -3.0014e-01,
#          -1.5045e-01, -3.4420e-02,  2.3438e-01, -2.6316e-01, -1.6929e-01,
#          -3.1812e-01,  2.8491e-02,  2.4117e-01,  3.7988e-01, -4.0420e-01,
#           1.1187e-01, -3.1301e-01,  1.8847e-01, -3.6723e-01, -4.9428e-02,
#          -2.5806e-02, -2.0594e-01, -5.0418e-01,  4.4840e-01, -2.5529e-01,
#           1.9476e-01,  1.9276e-01,  3.7716e-01, -1.2102e-01, -4.3806e-01,
#           2.7162e-01,  6.8225e-01,  5.9178e-02, -3.4279e-02, -7.2190e-02,
#          -6.2144e-02, -1.9367e-01, -2.1909e-01, -1.1777e+00, -1.5701e-01,
#          -6.8943e-02,  3.9091e-01, -2.4905e-02, -6.3518e-02,  6.4540e-02,
#           1.1943e-01,  2.4972e-01, -2.7323e-01, -6.2681e-02,  5.7051e-02,
#          -4.5492e-01, -5.3947e-01, -1.9599e-01,  4.4387e-01, -3.0630e-01,
#          -4.0094e-01, -1.0644e-01, -1.1607e-01,  2.9195e-01,  6.1044e-02,
#          -2.8611e-02,  2.7547e-01,  3.9325e-01,  7.5790e-02, -2.4191e-01,
#          -4.8555e-01, -5.7068e-02, -1.6127e-01,  8.0934e-02, -2.8832e-01,
#           3.5402e-01,  1.9980e-02,  1.6074e-01, -1.6229e+00,  8.0858e-02,
#          -7.3346e-03, -4.7431e-01,  2.2799e-02, -1.1785e-01,  1.4163e-03,
#          -1.1257e-01, -1.8870e-01, -1.5665e-01,  3.4124e-01, -3.4840e-01,
#           1.8915e-01,  2.4105e-01,  3.1330e-02,  4.2339e-01,  3.7070e-01,
#          -5.4079e-01, -2.4874e-01,  2.9759e-01, -2.5465e-01, -1.1415e-01,
#           2.2840e-01, -1.1364e-01,  4.0056e-01,  3.4452e-01, -1.2260e-01,
#           6.4177e-02, -3.9526e-01,  1.5926e-02, -1.4240e-01, -4.7101e-01,
#          -1.5559e-01,  3.4880e-01, -7.9241e-02, -1.3789e-01,  7.9340e-03,
#           8.9546e-02,  5.6778e-01,  9.6442e-02, -3.3093e-01,  1.9757e-01,
#           3.8860e-01,  3.7465e-01,  2.4894e-01, -7.8134e-02, -1.1647e-01,
#          -2.8735e-01, -1.9644e-01,  3.5908e-01,  3.9570e-01, -2.6253e-01,
#          -1.3155e-01, -1.9758e-01, -2.6147e-01, -3.0921e-02,  2.9365e-01,
#           2.0538e-01, -2.9601e-01, -6.0876e-02,  6.1182e-01, -2.5793e-01,
#           1.5872e-01,  2.9324e-01, -2.0468e-01, -5.5081e-02, -3.0186e-01,
#          -1.3052e-01, -1.9610e-01,  2.0653e-01, -3.3845e-01, -3.3498e-01,
#          -3.0368e-01, -6.9920e-01, -3.0498e-01,  1.2137e-01, -3.8901e-01,
#           3.4824e-02,  3.8397e-01, -7.6600e-02, -1.2051e-02,  2.8294e-01,
#           1.2271e-01,  1.4448e-01,  2.5137e-02, -2.3156e-02,  1.2741e-01,
#          -1.0861e-01,  2.5930e-02, -1.8285e-01, -6.4624e-02, -6.9627e-02,
#           5.2601e-01, -5.3122e-02,  1.3596e-01,  2.0743e-01,  6.1178e-01,
#          -2.4741e-01,  1.5597e-01, -2.5059e-01, -3.5678e-01, -2.1003e-01,
#           1.3083e-01, -1.8346e-01,  7.6047e-02, -2.0175e-01, -3.1020e-01,
#           9.0481e-02, -2.8370e-01, -1.8771e-01,  2.0045e-01, -2.5385e-01,
#           2.6109e-01,  3.0445e-01,  4.1918e-02, -1.9647e-01, -8.2685e-03,
#           4.7770e-01, -1.9577e-01,  4.5003e-01,  1.0947e-01,  5.5126e-01,
#           5.5087e-02, -4.3879e-03,  6.2451e-02, -3.0408e-01,  2.5376e-02,
#          -4.3116e-01, -1.4945e-01, -1.3920e-01,  1.6383e-01, -7.4205e-02,
#           2.2512e-01, -3.1332e-01, -6.2129e-02,  1.1040e-01,  1.0456e-01,
#           6.6000e-02,  2.0788e-01,  4.3263e-01,  5.5007e-01,  2.4159e-01,
#          -5.1502e-01,  1.7251e-02, -1.8422e-01,  2.6583e-01, -1.9581e-01,
#           5.5475e-01,  4.3278e-01,  1.0236e-01,  1.3196e-01, -2.3156e-01,
#           2.2005e-01, -1.4961e-01, -1.4971e-02, -3.1517e-01,  8.0751e-02,
#          -9.2402e-02, -2.0793e-01,  2.4657e-02, -1.5222e-01, -4.4845e-02,
#           8.2688e-02,  3.7697e-01, -1.8727e-01, -1.6987e-02,  5.5726e-01,
#           1.4820e-01, -2.7823e-01,  2.9100e-01,  4.2544e-01, -4.4398e-02,
#           2.4976e-01, -2.8901e-03, -2.6998e-02,  1.6537e-01,  1.7156e-01,
#          -2.9559e-01, -3.4663e-01,  1.0829e-01, -2.6553e-02, -6.0436e-01,
#          -3.5882e-01,  2.6408e-02,  1.5761e-01,  6.7572e-01, -3.4531e-01,
#          -4.3962e-01,  3.4966e-01,  1.9186e-01,  8.7364e-02, -1.5221e-01,
#          -2.2448e-01, -8.6076e-02, -2.6797e-01,  1.6855e-01,  3.7007e-01,
#           2.4181e-01, -6.0016e-02,  6.1614e-02,  4.3204e-01,  6.6516e-03,
#           1.2197e-01,  8.5467e-02,  9.0161e-02,  9.5483e-02,  2.6606e-01,
#           1.0242e-01, -5.4219e-01, -4.6969e-01,  1.2788e-01, -3.1055e-01,
#          -3.9647e-01, -2.7282e-01,  2.1181e-01,  4.6215e-01,  1.6518e-01,
#          -4.3291e-02,  2.6021e-01,  1.1900e-01, -8.0153e-01, -2.0707e-01,
#           2.8652e-01, -8.4198e-02, -1.3492e-01, -3.3572e-01, -3.6567e-01,
#          -1.7094e-01, -3.9152e-01, -6.6351e-02, -3.2224e-01,  2.8820e-01,
#           1.1824e-01,  1.3476e-02,  5.2148e-01,  1.1548e-01, -3.1536e-01,
#           2.0127e-02, -5.8261e-02,  3.5649e-01, -8.8139e-02, -5.1518e-01,
#          -1.4541e-01, -6.3269e-02,  1.5090e-01, -1.8503e-01,  2.1852e-02,
#           5.7808e-01,  3.6372e-01,  7.1254e-02, -2.9576e-01,  5.9326e-02,
#          -1.8046e-01, -2.6276e-01, -1.7184e-01, -1.9054e-01, -2.0902e-01,
#           4.1303e-02,  6.4972e-02, -1.0570e-01, -2.4426e-01,  1.8095e-01,
#           3.0557e-01, -6.6866e-02,  7.2660e-02,  2.9284e-02, -2.3460e-01,
#          -1.8341e-02,  3.1306e-01,  8.2058e-02, -2.0952e-02,  1.8448e-03,
#           1.9286e-01,  2.3778e-01, -5.6913e-01,  3.0540e-02,  4.9830e-01,
#          -4.3626e-01, -3.6212e-01, -2.0949e-02,  6.3894e-01,  3.6047e-01,
#           1.2337e-01, -9.2960e-02,  1.2971e-01, -2.7538e-01, -7.1093e-02,
#           1.4818e-01, -3.7013e-01, -5.6757e-01,  4.3334e-01, -1.7781e-01,
#          -3.5361e-02,  1.4970e-01, -8.2828e-02,  4.5395e-01, -2.7718e-01,
#           3.3656e-02, -5.3582e-01, -1.5298e-02, -2.8826e-02,  5.6882e-01,
#           2.6088e-01, -1.9990e-01,  8.2029e-02,  1.0365e-01, -2.0794e-01,
#          -6.9601e-02,  2.9185e-02,  1.4667e-01, -1.4960e-01, -2.0784e-01,
#           1.8220e-01,  4.7545e-01, -3.8543e-01,  9.3121e-02, -4.1789e-02,
#          -3.7197e-01,  4.9035e-02,  6.6212e-01,  1.7455e-01, -9.9551e-02,
#           2.0690e-01,  1.1259e-01,  2.2194e-01,  3.1518e-01, -6.3858e-01,
#          -4.0746e-01,  1.5355e-01,  3.5678e-01, -1.6583e-01,  1.5071e-01,
#          -7.8734e-02,  1.9384e-01,  2.0357e-01, -1.9500e-01,  1.5828e-01,
#           5.5222e-02, -2.0379e-01, -2.6363e-01, -3.7021e-02,  4.3053e-02,
#           1.3715e-01, -1.5856e-01, -4.8843e-03,  1.6345e-02, -1.9109e-01,
#          -8.8287e-02,  1.5719e-01, -8.4943e-02,  1.2328e-01,  1.7351e-01,
#          -1.9989e-01,  1.0940e-01, -2.7415e-01,  8.6573e-02,  2.7436e-01,
#           8.6832e-02, -1.7458e-01, -8.6953e-01,  2.9263e-01,  7.6618e-03,
#          -1.8903e-01, -1.2188e-01,  1.4999e-01,  3.7896e-01, -4.3904e-02,
#          -3.8229e-01, -5.1242e-01,  3.2197e-01,  9.9489e-02, -2.2148e-02,
#           5.1072e-01, -1.6128e-01, -2.9871e-02,  1.0243e-01, -2.3529e-01,
#           3.4833e-01, -4.0468e-01, -1.7577e-01,  2.1897e-01, -2.9988e-01,
#          -6.1128e-02, -4.7328e-01,  4.2736e-01, -1.3620e-01, -2.6114e-02,
#          -1.0220e-01,  1.6105e-01,  8.6220e-02,  4.0567e-01, -2.3592e-01,
#          -7.1145e-02, -2.4158e-01,  2.9234e-01, -1.8267e-01,  4.2520e-02,
#           2.4644e-01,  6.4975e-01,  3.5580e-01,  6.1804e-01, -3.0066e-01,
#          -4.2068e-01,  4.7615e-01, -8.0701e-02, -4.0381e-02,  2.6228e-01,
#           5.5396e-02, -2.6092e-01, -5.3806e-01, -1.5507e-01,  1.6490e-01,
#          -1.2426e+00,  3.7135e-01,  1.4430e-01,  4.9559e-03,  7.2042e-02,
#           1.8438e-01, -8.5412e-02, -2.6406e-01, -8.6485e-02, -1.2118e-01,
#           1.4300e-01,  6.9561e-01, -3.5704e-02,  2.8081e-02, -2.0279e-01,
#           2.5839e-01, -1.9080e-02, -1.5235e-02, -9.5495e-02,  2.4058e-01,
#           1.1758e-01,  1.9179e-01,  2.3336e-01,  8.7981e-02, -6.7324e-02,
#           9.7645e-03, -2.8451e-01, -3.2287e-01,  7.9603e-02, -3.9416e-02,
#           1.3273e-01, -2.4113e-01, -2.6625e+00, -7.0016e-01, -1.4585e-01,
#           7.0077e-02,  5.4513e-02, -6.9395e-02,  5.1016e-01, -1.0540e-01,
#          -7.1219e-03, -3.6583e-01,  4.4147e-03, -3.6405e-01,  3.4942e-01,
#          -1.3025e-01, -1.8933e-01, -1.9114e-01]])

# %% [markdown]
# ## 2. 中文句子向量
#
# 下载 [bert-base-chinese](https://huggingface.co/google-bert/bert-base-chinese) 的模型文件：
#
# ```bash
# conda install pytorch -y
# pip install -U huggingface_hub
# export HF_ENDPOINT=https://hf-mirror.com
# huggingface-cli download --resume-download bert-base-chinese --local-dir ./data/bert-base-chinese
# ```

# %%
# 加载模型
tokenizer = BertTokenizer.from_pretrained(CN_BERT_PATH)
model = BertModel.from_pretrained(CN_BERT_PATH)
# Out:
# Some weights of the model checkpoint at ./data/bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
cn_text = "阿美莉卡"
cn_encoded_input = tokenizer(cn_text, return_tensors='pt')
cn_encoded_input
# Out:
# {'input_ids': tensor([[ 101, 7350, 5401, 5799, 1305,  102]]), 'token_type_ids': tensor([[0, 0, 0, 0, 0, 0]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}

# %%
with torch.no_grad():
    cn_outputs = model(**cn_encoded_input)
    cn_embeddings = cn_outputs.last_hidden_state.mean(dim=1)

cn_embeddings.shape
# Out:
# torch.Size([1, 768])

# %%
cn_embeddings
# Out:
# tensor([[ 4.4131e-02,  6.0813e-02, -3.2073e-02, -8.2149e-02,  7.5614e-01,
#          -6.4655e-01, -4.7674e-01, -1.8938e-01, -5.8844e-02,  8.4807e-01,
#          -3.1951e-01, -2.3787e-01,  2.8421e-01, -3.4114e-01,  1.5973e+00,
#          -1.4003e-01,  7.1243e-01, -1.0589e+00,  1.3316e-01, -5.2681e-02,
#           6.0259e-01,  4.6172e-01, -8.3582e-01, -2.8237e-01,  6.0521e-01,
#          -1.0114e-02,  3.9432e-01, -1.0746e+00, -2.7550e-01, -3.6266e-02,
#          -7.7592e-01,  1.6510e-01, -9.8088e-01,  2.5674e-01,  6.2955e-01,
#           7.9850e-01, -3.7447e-01,  1.8022e-01, -5.0892e-01, -2.4844e-01,
#           4.9330e-01,  2.8054e-01, -3.7991e-01, -5.2307e-01,  1.1925e-01,
#          -4.2050e-01,  3.9872e-01, -9.3034e-02, -1.1711e-01,  1.0734e-01,
#          -1.0053e+00,  8.1617e+00,  2.8432e-02,  8.6318e-01,  7.6757e-02,
#           9.8966e-01,  7.6946e-01,  3.3368e-01,  5.5003e-01,  7.4619e-02,
#          -2.6159e-01, -4.5547e-02,  1.1871e-01,  1.0063e+00,  3.9679e-01,
#          -6.5552e-01, -3.7278e-01,  3.1115e-01, -7.2479e-01, -1.2628e+00,
#           1.7826e-01, -1.0023e+00,  7.1129e-01, -3.8581e-02,  1.7864e-01,
#           1.4567e-01,  3.4706e-01,  1.7645e-02, -6.8779e-01,  7.3581e-01,
#          -1.3211e-01,  6.1515e-01, -4.7834e-02, -1.0907e-01, -5.2469e-01,
#           7.0418e-02,  1.6502e-01, -1.2165e+00,  4.0539e-01, -3.2661e-01,
#           1.8813e-01,  6.6532e-02, -6.7017e-01,  8.6811e-01,  6.5250e-01,
#           2.9309e-01,  2.0187e-01,  7.3638e-01, -3.2067e-01, -8.2767e-01,
#          -7.5864e-01,  7.0001e-01,  6.9000e-01, -2.5335e-02, -8.1276e-01,
#           8.8137e-01, -4.7395e-01, -4.2188e-01, -5.3159e-01, -2.7518e-01,
#          -7.4137e-01,  9.4381e-02,  8.4147e-02,  3.5162e-01, -7.4892e-01,
#          -2.7483e-02,  2.4812e-01,  5.6889e-01, -8.3500e-01,  1.3276e-01,
#           1.6040e+00,  1.2883e-01, -4.6818e-01, -3.6504e-01,  1.6867e-01,
#          -1.6263e+00,  6.8341e-01,  6.5472e-01, -3.5781e-01,  4.9311e-01,
#          -5.7490e-01,  3.9062e-02, -3.0772e-01, -8.6442e-01,  3.4161e-01,
#          -4.2955e-01, -3.8391e-01,  8.9241e-02, -1.1766e+00,  4.7773e-01,
#           5.9163e-01, -7.0977e-01,  1.9624e-01,  4.2924e-01, -1.1073e-01,
#          -5.4240e-01,  1.2036e+00, -6.5781e-01,  2.6471e-01,  2.8465e-01,
#          -4.0639e-01, -1.7153e-01, -3.0581e-01, -1.8478e-01, -5.1745e-02,
#          -3.5828e-01, -4.4708e-01, -9.2830e-01, -1.7640e-01, -1.3064e-01,
#           1.9888e-01, -6.8331e-01,  7.8430e-02,  2.0852e-02,  5.8908e-01,
#          -1.7507e-01,  4.8784e-01, -3.0788e-01, -2.4145e-01,  1.2020e-01,
#          -2.2673e-01,  7.3946e-01,  2.1353e-01, -4.4205e-01, -7.0765e-01,
#           2.9526e-01, -2.9405e-01, -4.4696e-02, -5.8174e-01, -2.1894e-01,
#          -2.5334e-01,  3.1060e-01, -3.3345e-01,  1.2320e-01, -1.8782e-01,
#          -4.9350e-01,  3.3721e-01, -8.3224e-01,  2.6118e-01,  4.0189e-01,
#          -8.0982e-01,  1.0010e+00, -5.7300e-02, -4.8886e-01,  9.2609e-02,
#           8.1357e-01, -6.6165e-01, -3.4776e-01,  7.9288e-02,  2.8302e-01,
#          -2.1378e-01, -1.4001e-01,  2.4758e-01, -4.7335e-01, -5.6923e-01,
#           1.4078e-01, -8.9204e-01, -3.0821e-01,  6.5723e-01,  5.3828e-02,
#           2.3437e-01,  3.9346e-01, -1.7120e-01, -9.5161e-02, -4.5111e-02,
#          -1.9277e-01,  7.8836e-01, -1.8778e-01, -5.0253e-01, -6.0105e-01,
#           1.7938e-01,  3.4709e-01,  5.6246e-01, -4.9958e-01, -3.8991e-01,
#           5.7875e-03,  3.3457e-02,  5.9241e-01, -4.8629e-01, -5.8352e-01,
#           1.8192e-01, -8.2009e-02,  3.0044e-01,  1.0816e-01,  6.2220e-01,
#          -6.0054e-01, -1.4823e-02,  3.1454e-01, -6.9718e-01,  5.1164e-01,
#          -4.0225e-01, -8.7671e-01, -6.0504e-02, -1.3424e-02, -7.6855e-01,
#           2.4937e-01, -3.5733e-02,  1.9507e-02,  6.0319e-01,  3.9978e-01,
#           6.3879e-01, -2.4614e-01,  2.6424e-01, -8.9152e-01,  4.2984e-01,
#           1.7658e-01,  4.2145e-01, -8.6228e-01, -1.6286e-01, -4.2037e-01,
#           3.5355e-01, -4.4133e-01,  5.2000e-01,  4.6307e-01,  1.1106e+00,
#           1.6794e-01,  6.6448e-01, -6.1391e-01, -3.7160e-01,  3.8580e-04,
#          -1.8181e-01,  2.5822e-01, -5.4695e-02, -3.0267e-01, -7.8246e-01,
#          -2.3785e-01, -2.3389e-01, -4.5511e-01,  4.9206e-02, -2.2870e-01,
#           3.3700e-01, -3.2411e-01,  3.2357e-01, -6.6115e-02, -1.2784e-01,
#          -8.9554e-02,  3.1401e-01, -1.7254e-01, -6.7483e-01, -7.0736e-01,
#          -6.0699e-01, -7.3433e-02,  4.0740e-01, -2.7235e-01,  2.5287e+00,
#           5.3445e-01, -4.0064e-01, -2.1514e-01,  4.0210e-01, -7.6610e-01,
#          -3.0988e-01, -4.7385e-01, -6.1139e-01,  2.3035e-01,  9.3711e-01,
#          -6.2362e-01,  8.7801e-02,  1.0841e-01,  1.1700e-02,  5.2994e-02,
#           1.9149e-01, -2.5994e-02, -2.2015e-01, -1.2442e-01,  2.3526e-02,
#           8.5922e-03, -7.6254e-02, -3.7956e-02, -2.0232e-02,  3.7556e-01,
#          -1.8008e-01, -9.3337e-02,  2.1595e-01,  9.8668e-01,  4.4628e-01,
#          -1.4674e-02,  6.2633e-01, -3.8890e-01,  2.6636e-01, -7.8501e-02,
#           6.4780e-01,  2.2799e-01, -1.7657e-01,  4.0648e-01,  3.1654e-01,
#           3.9735e-01,  5.6961e-02,  5.0403e-01, -4.2631e-01, -1.8042e-01,
#           2.6006e-01, -8.6080e-01,  1.9668e-01,  2.2227e-01, -4.0502e-01,
#           1.3841e-01, -1.6464e-01, -4.9182e-01, -3.3906e-01,  1.3489e-01,
#          -1.5689e-01, -3.2314e-01, -5.7734e-01,  5.4652e-01, -8.2794e-01,
#           7.2755e-01, -3.1303e-02,  7.3521e-02,  3.9121e-01,  3.6906e-01,
#          -4.0283e-01,  9.7083e-02,  1.9939e-01, -1.0373e-02,  5.6936e-01,
#           1.0369e-01, -8.4101e-01,  1.6006e-01,  7.6184e-01, -5.9914e-01,
#          -9.7976e-03, -4.0399e-01,  9.1543e-01, -5.0219e-01,  3.8017e-01,
#          -1.2166e-01,  2.0111e-02,  4.3744e-01, -1.1864e-01,  1.4179e-01,
#          -2.1488e-01, -5.5691e-01,  2.4340e-01, -4.3440e-01, -7.1701e-02,
#          -1.9600e-01,  3.5108e-01, -6.5180e-01,  3.7723e-01,  1.9662e-01,
#          -5.6568e-01, -3.8888e-01, -6.9176e-01, -3.9826e-01, -9.4937e-01,
#           5.0129e-04,  2.7315e-01, -1.9648e-01, -4.2178e-01,  4.1960e-01,
#           3.8334e-01,  6.4314e-01,  2.5962e-01, -2.4899e-01,  1.2037e+00,
#          -5.1872e-01, -1.8021e-01,  3.3228e-01,  6.9591e-01, -6.7678e-01,
#          -2.2623e-01,  8.2010e-01,  2.1442e-01, -7.2605e-01, -3.1982e-01,
#           2.6666e-01, -1.8038e-01,  4.0026e-02,  4.4096e-02, -4.1543e-01,
#          -5.1037e-02,  4.0464e-01, -3.9755e-01,  6.2281e-02,  7.5873e-01,
#          -9.8906e-01,  5.1056e-01,  2.8547e-01,  4.3943e-01, -1.9624e-01,
#           8.0638e-03, -5.8816e-01, -8.4430e-01,  5.6269e-01,  7.2976e-01,
#           1.4459e-01,  1.6334e-02,  5.4030e-01, -3.9659e-01,  3.7948e-01,
#          -6.6521e-01, -3.3085e-01, -1.6564e-01,  2.5610e-02,  7.0107e-01,
#          -5.7083e-02, -2.2539e-01, -9.3522e-01,  1.9993e-01, -4.8934e-01,
#           1.0579e-01,  2.6253e-01, -1.0894e-01, -9.2421e-01,  5.3775e-01,
#          -6.7899e-02,  6.2594e-03, -3.4874e-01,  6.6905e-03,  5.9748e-01,
#           6.0931e-02,  5.7022e-01, -1.2031e-01,  8.1099e-01,  4.0732e-01,
#          -1.0307e-01, -2.7251e-01, -9.8907e-01,  2.9302e-01, -2.3761e-01,
#          -1.7099e-01,  1.1057e-01,  2.1368e-01,  8.2486e-02, -4.9700e-02,
#          -5.1197e-01, -2.6608e-01,  7.8966e-02, -1.1972e+00, -2.6066e-01,
#          -1.6470e-01, -3.0953e-01,  4.9192e-01, -1.2324e-01,  4.3516e-01,
#          -1.7028e-01,  5.4112e-01,  1.2198e+00, -5.2483e-01, -4.9802e-01,
#          -6.5239e-01, -1.9911e-01, -3.8460e-01, -3.8482e-01,  1.0962e-01,
#          -1.5920e+00,  1.3778e-01, -6.1734e-01, -5.5019e-02, -6.4648e-01,
#          -5.5019e-02, -6.2578e-01,  6.9604e-01, -6.2717e-02, -5.5148e-02,
#          -2.8806e-02, -2.4666e-01,  6.2300e-02, -5.1834e-01, -2.2341e-01,
#           8.1658e-01, -9.1464e-01, -5.5625e-01, -8.3639e-01,  1.0778e+00,
#          -2.4861e-01, -5.1013e-01, -4.8987e-01,  6.3805e-01,  1.4984e-01,
#           3.4870e-01,  1.6356e-01, -2.1795e-01, -1.2456e-01,  3.6510e-01,
#          -3.1464e-01,  2.1147e-01,  5.7319e-01,  2.5797e-02,  1.0568e+00,
#           7.0644e-02,  2.3973e-01,  4.8261e-01, -7.6334e-01,  1.5667e+00,
#           6.3301e-01,  3.9537e-01, -4.3450e-01, -7.0652e-02,  4.3854e-01,
#          -2.9181e-01, -3.9567e-01,  4.9299e-01,  6.8416e-01, -1.9142e-01,
#          -4.9424e-01,  1.4904e-01,  2.0068e-01, -3.4944e-01,  1.2926e-01,
#          -4.9136e-01,  1.2816e+00, -6.0984e-01,  7.0169e-01, -1.5012e-01,
#          -5.2012e-01, -2.4483e-01, -1.2355e-01,  1.3693e-01, -2.8178e-01,
#          -1.7607e-01,  3.5956e-02, -1.6916e-01, -5.8799e-01, -2.5358e-01,
#           2.7519e-01, -1.8937e-01, -7.5262e-01, -9.9369e-01,  1.7070e-01,
#          -4.5928e-01,  3.6417e-01, -1.9462e-02,  2.2909e-01,  2.7742e-01,
#           2.2864e-01, -8.0800e-01, -9.7538e-02,  5.5043e-01, -2.4987e-01,
#           2.0277e-01,  3.5036e-01, -4.5665e-01, -1.1221e-01, -7.1436e-01,
#          -9.0535e-01,  1.5618e-01, -1.2729e-02, -1.8959e-01, -1.1627e-02,
#           3.6941e-01,  9.9609e-02, -4.2879e-01,  3.9170e-01, -9.7557e-02,
#          -2.2148e-03,  1.8301e-01, -5.0093e-01,  3.2981e-03,  9.5048e-02,
#          -2.2835e-01,  4.7604e-01,  2.1985e-01, -3.5545e-01,  1.5642e-01,
#          -7.4542e-01,  1.0644e+00,  2.9452e-02, -3.5543e-01, -9.2468e-01,
#          -2.5138e-01, -1.0306e-01,  2.1325e-01, -5.7650e-01, -9.1363e-01,
#          -5.6395e-02,  1.5966e-01,  4.4517e-01,  4.8765e-02, -5.5228e-01,
#          -2.7849e-01, -5.1462e-01, -2.5276e-01, -1.3015e-01,  1.4002e-01,
#           1.1607e-01,  9.0400e-01, -5.3177e-01, -4.6013e-02,  1.9224e-02,
#          -7.2516e-02, -3.1126e-02, -3.6119e-01,  1.6917e-01, -3.1921e-01,
#          -3.3431e-01,  1.9207e-01,  6.3599e-02,  2.0088e-01, -6.7819e-01,
#           4.3105e-01, -1.9674e-01, -8.5830e-01, -8.0376e-01, -2.2305e-01,
#          -3.7931e-01,  5.3200e-01, -4.4796e-01,  1.0322e-01,  1.0712e-01,
#           2.7180e-01,  3.0862e-01,  2.3625e-01,  3.7514e-01,  5.0822e-01,
#           2.8092e-01,  5.9058e-01, -7.0398e-01, -2.1092e-01, -3.7182e-01,
#           3.8136e-01, -7.8040e-01,  5.3531e-01,  3.7629e-01,  3.3122e-01,
#          -4.3372e-01,  2.0239e-01, -2.3593e-01,  9.2337e-01,  1.4707e-01,
#           1.0643e+00, -3.2069e-01,  9.8262e-01,  1.0857e-01,  7.7002e-02,
#           4.7291e-01, -3.5890e-02, -8.7900e-01, -6.2263e-01, -3.4695e-01,
#           1.8368e-01, -7.5402e-02,  7.0511e-01,  2.3349e-01, -6.2498e-01,
#          -6.3201e-01, -9.5759e-01, -8.3247e-01,  5.8944e-01,  3.5208e-01,
#          -3.6097e-01,  8.1187e-01,  6.1395e-01, -3.2117e-01, -3.0198e-01,
#           2.8913e+00, -5.2205e-01,  8.9876e-01,  3.6973e-01, -7.9642e-02,
#           3.5569e-01, -8.7403e-02, -2.1212e-01, -6.3972e-01, -2.8217e-01,
#           6.6963e-03, -1.0580e-01,  3.6903e-01, -7.0521e-02,  2.0146e-01,
#           2.7115e-01,  4.5934e-01,  5.1612e-01, -4.5426e-01,  3.2592e-02,
#           4.6948e-01, -1.3840e-01, -1.1875e+00, -1.3499e+00,  3.1642e-01,
#           1.8747e-01, -8.1324e-01,  3.4609e-01, -1.0205e-01,  1.4182e-01,
#          -1.6620e-01, -3.2840e-02,  3.0287e-01,  7.2032e-01, -3.2572e-01,
#           3.9762e-01,  4.4740e-01,  2.0896e-01,  7.7597e-01,  1.0682e-01,
#           5.2579e-01,  6.8464e-01,  3.8959e-01,  3.8935e-01,  2.8942e-01,
#           4.7876e-01, -5.5053e-01, -7.8241e-01,  2.4667e-01, -2.9615e-01,
#           1.5053e-01,  6.2716e-03, -1.4829e-01, -3.7183e-01,  1.0443e+00,
#           1.8495e-01, -1.3294e-01,  9.2481e-01, -3.7338e-01,  4.8614e-01,
#          -2.9398e-01,  1.8022e+00,  6.1277e-01,  4.0220e-02, -3.5421e-01,
#           1.1476e-01,  4.2523e-02,  7.0530e-02, -4.1947e-01, -1.0203e-01,
#           2.6806e-01,  2.4756e-01, -7.5913e-02]])

# %% [markdown]
# 其他可用的中文Embedding模型
#
# - https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2
# - https://huggingface.co/hfl/chinese-roberta-wwm-ext
# - https://huggingface.co/uer/sbert-base-chinese-nli
